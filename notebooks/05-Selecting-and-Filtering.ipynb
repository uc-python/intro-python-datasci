# %%
from slide_tools import hide_code_in_slideshow

# %% [markdown]
# # Selecting and Filtering

# %% [markdown]
# > “Every second of every day, our senses bring in way too much data than we can possibly process in our brains.”
# >
# > \- Peter Diamandis, Founder of the X-Prize for human-AI collaboration

# %% [markdown]
# ## Applied Review

# %% [markdown]
# ### Data Structures and the DataFrame Class

# %% [markdown]
# * Data is frequently represented inside a **DataFrame** - a class from the `pandas` library that is similar to a *table* or *dataset*

# %% [markdown]
# * Each DataFrame object has rows and columns

# %% [markdown]
# * The DataFrame class has methods (built-in operations) for common tasks and attributes (stored data) of common information

# %% [markdown]
# * Other structures exist, too - dicts, models, etc.

# %% [markdown]
# ### Importing Data

# %% [markdown]
# * Tabular data can be imported into DataFrames using the `pd.read_csv()` function - there are parameters for different options

# %%
import pandas as pd
planes_df = pd.read_csv('../data/planes.csv')

# %% [markdown]
# * Other data formats like JSON (key-value pairs) and Pickle (native Python) can be imported using the `with` statement and respective functions:
#   * JSON files use the `load()` function from the `json` library
#   * Pickle files use the `load()` function from the `pickle` library

# %% [markdown]
# ## General Model

# %% [markdown]
# ### Subsetting Dimensions

# %% [markdown]
# * We don't always want all of the data in a DataFrame, so we need to take subsets of the DataFrame.

# %% [markdown]
# * In general, **subsetting** is extracting a small portion of a DataFrame -- making the DataFrame smaller.

# %% [markdown]
# * Since the DataFrame is two-dimensional, there are two dimensions on which to subset.

# %% [markdown]
# **Dimension 1:** We may only want to consider certain *variables*.

# %% [markdown]
# For example, we may only care about the `year` and `engines` variables:

# %%
hide_code_in_slideshow()
planes_df.head().style.apply(lambda x: ['background: lightblue' if x.name == 'engines' or x.name == 'year' else '' for i,_ in x.iteritems()])
# Out:
# <div id="d5e61567e45b250c"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#d5e61567e45b250c");
#             if (p.length==0) return;
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>
# <style  type="text/css" >
#     #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col1 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col5 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col1 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col5 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col1 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col5 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col1 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col5 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col1 {
#             background:  lightblue;
#         }    #T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col5 {
#             background:  lightblue;
#         }</style><table id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >tailnum</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >manufacturer</th>        <th class="col_heading level0 col4" >model</th>        <th class="col_heading level0 col5" >engines</th>        <th class="col_heading level0 col6" >seats</th>        <th class="col_heading level0 col7" >speed</th>        <th class="col_heading level0 col8" >engine</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col0" class="data row0 col0" >N10156</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col1" class="data row0 col1" >2004.000000</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col2" class="data row0 col2" >Fixed wing multi engine</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col3" class="data row0 col3" >EMBRAER</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col4" class="data row0 col4" >EMB-145XR</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col6" class="data row0 col6" >55</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row0_col8" class="data row0 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col0" class="data row1 col0" >N102UW</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col1" class="data row1 col1" >1998.000000</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col2" class="data row1 col2" >Fixed wing multi engine</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col3" class="data row1 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col4" class="data row1 col4" >A320-214</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col6" class="data row1 col6" >182</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row1_col8" class="data row1 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col0" class="data row2 col0" >N103US</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col1" class="data row2 col1" >1999.000000</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col2" class="data row2 col2" >Fixed wing multi engine</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col3" class="data row2 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col4" class="data row2 col4" >A320-214</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col5" class="data row2 col5" >2</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col6" class="data row2 col6" >182</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row2_col8" class="data row2 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col0" class="data row3 col0" >N104UW</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col1" class="data row3 col1" >1999.000000</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col2" class="data row3 col2" >Fixed wing multi engine</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col3" class="data row3 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col4" class="data row3 col4" >A320-214</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col5" class="data row3 col5" >2</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col6" class="data row3 col6" >182</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row3_col8" class="data row3 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col0" class="data row4 col0" >N10575</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col1" class="data row4 col1" >2002.000000</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col2" class="data row4 col2" >Fixed wing multi engine</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col3" class="data row4 col3" >EMBRAER</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col4" class="data row4 col4" >EMB-145LR</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col5" class="data row4 col5" >2</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col6" class="data row4 col6" >55</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col7" class="data row4 col7" >nan</td>
#                         <td id="T_3dbd8bda_c32b_11ea_a4b5_f40f2435e9f7row4_col8" class="data row4 col8" >Turbo-fan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# We call this **selecting** columns/variables -- this is similar SQL's `SELECT` or R's dplyr package's `select()`.

# %% [markdown]
# **Dimension 2:** We may only want to consider certain *cases*.

# %% [markdown]
# For example, we may only care about the cases where the manufacturer is Embraer.

# %%
hide_code_in_slideshow()
planes_df.head().style.apply(lambda x: ['background: lightgreen' if i in [0, 4] else '' for i,_ in x.iteritems()])
# Out:
# <div id="534eac11e6e73af4"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#534eac11e6e73af4");
#             if (p.length==0) return;
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>
# <style  type="text/css" >
#     #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col0 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col1 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col2 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col3 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col4 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col5 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col6 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col7 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col8 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col0 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col1 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col2 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col3 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col4 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col5 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col6 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col7 {
#             background:  lightgreen;
#         }    #T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col8 {
#             background:  lightgreen;
#         }</style><table id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >tailnum</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >manufacturer</th>        <th class="col_heading level0 col4" >model</th>        <th class="col_heading level0 col5" >engines</th>        <th class="col_heading level0 col6" >seats</th>        <th class="col_heading level0 col7" >speed</th>        <th class="col_heading level0 col8" >engine</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col0" class="data row0 col0" >N10156</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col1" class="data row0 col1" >2004.000000</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col2" class="data row0 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col3" class="data row0 col3" >EMBRAER</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col4" class="data row0 col4" >EMB-145XR</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col6" class="data row0 col6" >55</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row0_col8" class="data row0 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col0" class="data row1 col0" >N102UW</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col1" class="data row1 col1" >1998.000000</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col2" class="data row1 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col3" class="data row1 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col4" class="data row1 col4" >A320-214</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col6" class="data row1 col6" >182</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row1_col8" class="data row1 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col0" class="data row2 col0" >N103US</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col1" class="data row2 col1" >1999.000000</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col2" class="data row2 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col3" class="data row2 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col4" class="data row2 col4" >A320-214</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col5" class="data row2 col5" >2</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col6" class="data row2 col6" >182</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row2_col8" class="data row2 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col0" class="data row3 col0" >N104UW</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col1" class="data row3 col1" >1999.000000</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col2" class="data row3 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col3" class="data row3 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col4" class="data row3 col4" >A320-214</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col5" class="data row3 col5" >2</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col6" class="data row3 col6" >182</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row3_col8" class="data row3 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col0" class="data row4 col0" >N10575</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col1" class="data row4 col1" >2002.000000</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b5_f40f2435e9f7row4_col2" class="data row4 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e2aeaa4_c32b_11ea_a4b

# %% [markdown]
# We call this **filtering** or **slicing** -- this is similar to SQL's `WHERE` or R's dplyr package's `filter()` or `slice()`.

# %% [markdown]
# And we can combine these two options to subset in both dimensions -- the `year` and `engines` variables where the manufacturer is Embraer:

# %%
hide_code_in_slideshow()
planes_df.head().style.apply(lambda x: ['background: teal' if i in [0, 4] and (x.name == 'engines' or x.name == 'year') else '' for i,_ in x.iteritems()])
# Out:
# <div id="66584c34dec71ae8"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#66584c34dec71ae8");
#             if (p.length==0) return;
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>
# <style  type="text/css" >
#     #T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col1 {
#             background:  teal;
#         }    #T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col5 {
#             background:  teal;
#         }    #T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col1 {
#             background:  teal;
#         }    #T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col5 {
#             background:  teal;
#         }</style><table id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >tailnum</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >manufacturer</th>        <th class="col_heading level0 col4" >model</th>        <th class="col_heading level0 col5" >engines</th>        <th class="col_heading level0 col6" >seats</th>        <th class="col_heading level0 col7" >speed</th>        <th class="col_heading level0 col8" >engine</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col0" class="data row0 col0" >N10156</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col1" class="data row0 col1" >2004.000000</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col2" class="data row0 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col3" class="data row0 col3" >EMBRAER</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col4" class="data row0 col4" >EMB-145XR</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col6" class="data row0 col6" >55</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row0_col8" class="data row0 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col0" class="data row1 col0" >N102UW</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col1" class="data row1 col1" >1998.000000</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col2" class="data row1 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col3" class="data row1 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col4" class="data row1 col4" >A320-214</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col6" class="data row1 col6" >182</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row1_col8" class="data row1 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col0" class="data row2 col0" >N103US</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col1" class="data row2 col1" >1999.000000</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col2" class="data row2 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col3" class="data row2 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col4" class="data row2 col4" >A320-214</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col5" class="data row2 col5" >2</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col6" class="data row2 col6" >182</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row2_col8" class="data row2 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col0" class="data row3 col0" >N104UW</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col1" class="data row3 col1" >1999.000000</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col2" class="data row3 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col3" class="data row3 col3" >AIRBUS INDUSTRIE</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col4" class="data row3 col4" >A320-214</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col5" class="data row3 col5" >2</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col6" class="data row3 col6" >182</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col7" class="data row3 col7" >nan</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row3_col8" class="data row3 col8" >Turbo-fan</td>
#             </tr>
#             <tr>
#                         <th id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col0" class="data row4 col0" >N10575</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col1" class="data row4 col1" >2002.000000</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col2" class="data row4 col2" >Fixed wing multi engine</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col3" class="data row4 col3" >EMBRAER</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col4" class="data row4 col4" >EMB-145LR</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col5" class="data row4 col5" >2</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col6" class="data row4 col6" >55</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col7" class="data row4 col7" >nan</td>
#                         <td id="T_3e9a8c4c_c32b_11ea_a4b5_f40f2435e9f7row4_col8" class="data row4 col8" >Turbo-fan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Subsetting into a New DataFrame

# %% [markdown]
# In the previous example, we want to do two things using `planes_df`:
#
#   1. **select** the `year` and `engines` variables
#   2. **filter** to cases where the manufacturer is Embraer

# %% [markdown]
# But we also want to return a new DataFrame -- not just highlight certain cells.

# %% [markdown]
# In other words, we want to turn this:

# %%
planes_df.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %% [markdown]
# Into this:

# %%
planes_df.head()[planes_df.head()['manufacturer'] == 'EMBRAER'][['year', 'engines']]
# Out:
#      year  engines
# 0  2004.0        2
# 4  2002.0        2

# %% [markdown]
# So we really have a third need: return the resulting DataFrame so we can continue our analysis:
#
#   1. **select** the `year` and `engines` variables
#   2. **filter** to cases where the manufacturer is Embraer
#   3. Return a DataFrame to continue the analysis

# %% [markdown]
# ## Subsetting Variables

# %% [markdown]
# Recall that the subsetting of variables/columns is called **selecting** variables/columns.

# %% [markdown]
# In a simple example, we can select a single variable using bracket subsetting notation:

# %%
planes_df['year'].head()
# Out:
# 0    2004.0
# 1    1998.0
# 2    1999.0
# 3    1999.0
# 4    2002.0
# Name: year, dtype: float64

# %% [markdown]
# Notice the `head()` method also works on `planes_df['year']` to return the first five elements.

# %% [markdown]
# <font class="question">
#     <strong>Question</strong>:<br><em>What is the data type of <code>planes_df['year']</code>?</em>
# </font>

# %% [markdown]
# This returns `pandas.core.series.Series`, referred to simply as a "Series", rather than a DataFrame.

# %%
type(planes_df['year'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# This is okay -- the Series is a popular data structure in Python:

# %% [markdown]
# * A Series is a one-dimensional data structure -- this is similar to a Python `list`

# %% [markdown]
# * Note that all objects in a Series must be of the same type

# %% [markdown]
# * Each DataFrame can be thought of as a list of equal-length Series (plus an Index)

# %% [markdown]
# This visual of a Series and DataFrame may be helpful:
#
# <center>
# <img src="images/dataframe-series.png" alt="dataframe-series.png" width="600" height="600">
# </center>

# %% [markdown]
# Series can be useful for other things, and we will cover that later -- but for now, we are interested in *returning a DataFrame* rather than a series.

# %% [markdown]
# We can select a single variable and return a DataFrame by still using bracket subsetting notation, but this time we will pass a `list` of variables names:

# %%
planes_df[['year']].head()
# Out:
#      year
# 0  2004.0
# 1  1998.0
# 2  1999.0
# 3  1999.0
# 4  2002.0

# %% [markdown]
# And we can see that we've returned a DataFrame:

# %%
type(planes_df[['year']].head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <font class="question">
#     <strong>Question</strong>:<br><em>What's another advantage of this passing a <code>list</code>?</em>
# </font>

# %% [markdown]
# Passing a list into the bracket subsetting notation allows us to select multiple variables at once:

# %%
planes_df[['year', 'engines']].head()
# Out:
#      year  engines
# 0  2004.0        2
# 1  1998.0        2
# 2  1999.0        2
# 3  1999.0        2
# 4  2002.0        2

# %% [markdown]
# In another example, assume we are interested in the `model` of plane, number of `seats` and `engine` type:

# %%
planes_df[['model', 'seats', 'engine']].head()
# Out:
#        model  seats     engine
# 0  EMB-145XR     55  Turbo-fan
# 1   A320-214    182  Turbo-fan
# 2   A320-214    182  Turbo-fan
# 3   A320-214    182  Turbo-fan
# 4  EMB-145LR     55  Turbo-fan

# %% [markdown]
# <font class="your_turn">
#     Your Turn
# </font>
#
# 1\. ______ is a common term for subsetting DataFrame variables.
#
# 2\. What type of object is a DataFrame column?
#
# 3\. What will be returned by the following code?
#
#    ```python
#    planes_df['type', 'model']
#    ```

# %% [markdown]
# ## Subsetting Cases

# %% [markdown]
# When we subset cases/records/rows we primarily use two names: **slicing** and **filtering**, but *these are not the same*:
#
#   * **slicing**, similar to row **indexing**, subsets cases by the value of the Index
#   * **filtering** subsets cases using a conditional test

# %% [markdown]
# ### Slicing Cases

# %% [markdown]
# Remember that all DataFrames have an Index:

# %%
planes_df.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %% [markdown]
# We can **slice** cases/rows using the values in the Index and bracket subsetting notation. It's common practice to use `.loc` to slice cases/rows:

# %%
planes_df.loc[0:5]
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
# 5  N105UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan
# 5        2    182    NaN  Turbo-fan

# %% [markdown]
# Note that since this is *not* "indexing", the last element is inclusive.

# %% [markdown]
# We can also pass a `list` of Index values:

# %%
planes_df.loc[[0, 2, 4, 6, 8]]
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
# 6  N107US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 8  N109UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan
# 6        2    182    NaN  Turbo-fan
# 8        2    182    NaN  Turbo-fan

# %% [markdown]
# ### Filtering Cases

# %% [markdown]
# We can **filter** cases/rows using a logical sequence equal in length to the number of rows in the DataFrame.

# %% [markdown]
# Continuing our example, assume we want to determine whether each case's `manufacturer` is Embraer. We can use the `manufacturer` Series and a logical equivalency test to find the result for each row:

# %%
planes_df['manufacturer'].head() == 'EMBRAER'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: manufacturer, dtype: bool

# %% [markdown]
# We can use this resulting logical sequence to test **filter** cases -- rows that are `True` will be returned while those that are `False` will be removed:

# %%
planes_df[planes_df['manufacturer'] == 'EMBRAER'].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 4   N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR        2
# 10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 4      55    NaN  Turbo-fan
# 10     55    NaN  Turbo-fan
# 11     55    NaN  Turbo-fan
# 12     55    NaN  Turbo-fan

# %% [markdown]
# This also works with `.loc`:

# %%
planes_df.loc[planes_df['manufacturer'] == 'EMBRAER'].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 4   N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR        2
# 10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 4      55    NaN  Turbo-fan
# 10     55    NaN  Turbo-fan
# 11     55    NaN  Turbo-fan
# 12     55    NaN  Turbo-fan

# %% [markdown]
# Any conditional test can be used to **filter** DataFrame rows:

# %%
planes_df.loc[planes_df['year'] > 2002].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 15     55    NaN  Turbo-fan
# 16     55    NaN  Turbo-fan
# 17     55    NaN  Turbo-fan
# 18     55    NaN  Turbo-fan

# %% [markdown]
# And multiple conditional tests can be combined using logical operators:

# %%
planes_df.loc[(planes_df['year'] > 2002) & (planes_df['year'] < 2004)].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 19  N11150  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 15     55    NaN  Turbo-fan
# 16     55    NaN  Turbo-fan
# 17     55    NaN  Turbo-fan
# 18     55    NaN  Turbo-fan
# 19     55    NaN  Turbo-fan

# %% [markdown]
# Note that each condition is wrapped in parentheses -- this is required.

# %% [markdown]
# <font class="your_turn">
#     Your Turn
# </font>
#
# 1. What's the difference between **slicing** cases and **filtering** cases?
# 2. Fill in the blanks to fix the following code to find planes that have more than three engines:
#
#    ```python
#     planes_df.loc[______['______'] > 3]
#    ```

# %% [markdown]
# ### Selecting Variables and Filtering Cases

# %% [markdown]
# If we want to select variables and filter cases at the same time, we have a few options:
#
# 1. Sequential operations
# 2. Simultaneous operations

# %% [markdown]
# #### Sequential Operations
#
# We can use what we've previously learned to select variables and filter cases in multiple steps:

# %%
planes_df_filtered = planes_df.loc[planes_df['manufacturer'] == 'EMBRAER']
planes_df_filtered_and_selected = planes_df_filtered[['year', 'engines']]
planes_df_filtered_and_selected.head()
# Out:
#       year  engines
# 0   2004.0        2
# 4   2002.0        2
# 10  2002.0        2
# 11  2002.0        2
# 12  2002.0        2

# %% [markdown]
# This is a good way to learn how to select and filter independently, and it also reads very clearly.

# %% [markdown]
# #### Simultaneous Operations
#
# However, we can also do both selecting and filtering in a single step with `.loc`:

# %%
planes_df.loc[planes_df['manufacturer'] == 'EMBRAER', ['year', 'engines']].head()
# Out:
#       year  engines
# 0   2004.0        2
# 4   2002.0        2
# 10  2002.0        2
# 11  2002.0        2
# 12  2002.0        2

# %% [markdown]
# This option is more succinct and also reduces programming time.

# %% [markdown]
# <font class="your_turn">
#     Your Turn
# </font>
#
# 1. Subset `planes_df` to only include planes made by Boeing and the `seats` and `model` variables.

# %% [markdown]
# ## Questions
#
# Are there any questions before we move on?
